# %% [markdown]
# # Milestone 2
#
# Fix data preprocessing and observe effect on training with various data patterns.

# %%
import pandas as pd
import numpy as np
from collections import Counter
from matplotlib import pyplot as plt
import seaborn as sns
import re

# %%
processed_data=pd.read_csv("puppymerged_num.csv")

# %%
from sklearn.preprocessing import LabelEncoder, LabelBinarizer

OHE_columns = {}

# Encode Values into a new column
def column_encode(df, col_name):
    lb_make = LabelEncoder()
    df[col_name + "_encoded"] = lb_make.fit_transform(df[col_name])

# One Hot Encoder
def one_hot_encode(df, col_name):
    lb_style = LabelBinarizer()
    lb_results = lb_style.fit_transform(df[col_name])
    new_df = pd.DataFrame(lb_results, columns=lb_style.classes_)
    
    # Add new_df to df
    print("New columns added:")
    for x in new_df:
        new_col_name = str(col_name) + "-" + str(x)
        if isinstance(x, np.float64):
            new_col_name = str(col_name) + "-" + str(int(x))
            
        df[new_col_name] = new_df[x]
        print(" * " + new_col_name)
        
        if col_name not in OHE_columns:
            OHE_columns[col_name] = []
        OHE_columns[col_name].append(new_col_name)

# %%
columns_to_OHE = [
   "ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear", "FriendlyWAnimals", "RespondsToCommandKennel", "Health", "TrafficFear", "SitsOnCommand", "GoodWKids", "StoolFirm", "DownOnCommand", "EliminationInHouse", "GoodWStrangers", "EliminationInCrate", "Breed"
]
for col in columns_to_OHE:
    column_encode(processed_data, col)
    one_hot_encode(processed_data, col)
# Out:
# New columns added:
#  * ExceriseAmount-0
#  * ExceriseAmount-1
#  * ExceriseAmount-2
#  * ExceriseAmount-3
#  * ExceriseAmount-4
#  * ExceriseAmount-5
#  * ExceriseAmount-6
# New columns added:
#  * NailCutting-0
#  * NailCutting-1
#  * NailCutting-2
#  * NailCutting-3
#  * NailCutting-4
#  * NailCutting-5
# New columns added:
#  * StaysOnCommand-0
#  * StaysOnCommand-1
#  * StaysOnCommand-2
#  * StaysOnCommand-3
#  * StaysOnCommand-4
#  * StaysOnCommand-5
# New columns added:
#  * AttendsHomeSwitches-0
#  * AttendsHomeSwitches-1
#  * AttendsHomeSwitches-2
#  * AttendsHomeSwitches-3
#  * AttendsHomeSwitches-4
#  * AttendsHomeSwitches-5
# New columns added:
#  * BehavesWellClass-0
#  * BehavesWellClass-1
#  * BehavesWellClass-2
#  * BehavesWellClass-3
#  * BehavesWellClass-4
#  * BehavesWellClass-5
# New columns added:
#  * ChasingAnimals-0
#  * ChasingAnimals-1
#  * ChasingAnimals-2
#  * ChasingAnimals-3
#  * ChasingAnimals-4
#  * ChasingAnimals-5
# New columns added:
#  * JumpOnPeople-0
#  * JumpOnPeople-1
#  * JumpOnPeople-2
#  * JumpOnPeople-3
#  * JumpOnPeople-4
#  * JumpOnPeople-5
# New columns added:
#  * LeftUnattended-0
#  * LeftUnattended-1
#  * LeftUnattended-2
#  * LeftUnattended-3
#  * LeftUnattended-4
#  * LeftUnattended-5
# New columns added:
#  * BarksExcessively-0
#  * BarksExcessively-1
#  * BarksExcessively-2
#  * BarksExcessively-3
#  * BarksExcessively-4
#  * BarksExcessively-5
# New columns added:
#  * PlaybitePeople-0
#  * PlaybitePeople-1
#  * PlaybitePeople-2
#  * PlaybitePeople-3
#  * PlaybitePeople-4
#  * PlaybitePeople-5
# New columns added:
#  * EliminatesOnRoute-0
#  * EliminatesOnRoute-1
#  * EliminatesOnRoute-2
#  * EliminatesOnRoute-3
#  * EliminatesOnRoute-4
#  * EliminatesOnRoute-5
# New columns added:
#  * RaidsGarbage-0
#  * RaidsGarbage-1
#  * RaidsGarbage-2
#  * RaidsGarbage-3
#  * RaidsGarbage-4
#  * RaidsGarbage-5
# New columns added:
#  * CanGivePills-0
#  * CanGivePills-1
#  * CanGivePills-2
#  * CanGivePills-3
#  * CanGivePills-4
#  * CanGivePills-5
# New columns added:
#  * Color-1
#  * Color-2
#  * Color-3
#  * Color-4
#  * Color-5
# New columns added:
#  * OnFurniture-0
#  * OnFurniture-1
#  * OnFurniture-2
#  * OnFurniture-3
#  * OnFurniture-4
#  * OnFurniture-5
# New columns added:
#  * EarCleaning-0
#  * EarCleaning-1
#  * EarCleaning-2
#  * EarCleaning-3
#  * EarCleaning-4
#  * EarCleaning-5
# New columns added:
#  * CounterSurfingJumpOnDoors-0
#  * CounterSurfingJumpOnDoors-1
#  * CounterSurfingJumpOnDoors-2
#  * CounterSurfingJumpOnDoors-3
#  * CounterSurfingJumpOnDoors-4
#  * CounterSurfingJumpOnDoors-5
# New columns added:
#  * WalksWellOnLeash-0
#  * WalksWellOnLeash-1
#  * WalksWellOnLeash-2
#  * WalksWellOnLeash-3
#  * WalksWellOnLeash-4
#  * WalksWellOnLeash-5
# New columns added:
#  * ComeOffLeash-0
#  * ComeOffLeash-1
#  * ComeOffLeash-2
#  * ComeOffLeash-3
#  * ComeOffLeash-4
#  * ComeOffLeash-5
# New columns added:
#  * NoInappropriateChewing-0
#  * NoInappropriateChewing-1
#  * NoInappropriateChewing-2
#  * NoInappropriateChewing-3
#  * NoInappropriateChewing-4
#  * NoInappropriateChewing-5
# New columns added:
#  * AttendsClasses-0
#  * AttendsClasses-1
#  * AttendsClasses-2
#  * AttendsClasses-3
#  * AttendsClasses-4
#  * AttendsClasses-5
# New columns added:
#  * Stairs-0
#  * Stairs-1
#  * Stairs-2
#  * Stairs-3
#  * Stairs-4
#  * Stairs-5
# New columns added:
#  * StealsFood-0
#  * StealsFood-1
#  * StealsFood-2
#  * StealsFood-3
#  * StealsFood-4
#  * StealsFood-5
# New columns added:
#  * KnowCommandGetBusy-0
#  * KnowCommandGetBusy-1
#  * KnowCommandGetBusy-2
#  * KnowCommandGetBusy-3
#  * KnowCommandGetBusy-4
#  * KnowCommandGetBusy-5
# New columns added:
#  * QuietInCrate-0
#  * QuietInCrate-1
#  * QuietInCrate-2
#  * QuietInCrate-3
#  * QuietInCrate-4
#  * QuietInCrate-5
# New columns added:
#  * Housemanners-0
#  * Housemanners-1
#  * Housemanners-2
#  * Housemanners-3
#  * Housemanners-4
#  * Housemanners-5
# New columns added:
#  * ComeOnLeash-0
#  * ComeOnLeash-1
#  * ComeOnLeash-2
#  * ComeOnLeash-3
#  * ComeOnLeash-4
#  * ComeOnLeash-5
# New columns added:
#  * EnergyLevel-0
#  * EnergyLevel-1
#  * EnergyLevel-2
#  * EnergyLevel-3
#  * EnergyLevel-4
#  * EnergyLevel-5
# New columns added:
#  * NoiseFear-0
#  * NoiseFear-1
#  * NoiseFear-2
#  * NoiseFear-3
#  * NoiseFear-4
#  * NoiseFear-5
# New columns added:
#  * FriendlyWAnimals-0
#  * FriendlyWAnimals-1
#  * FriendlyWAnimals-2
#  * FriendlyWAnimals-3
#  * FriendlyWAnimals-4
#  * FriendlyWAnimals-5
# New columns added:
#  * RespondsToCommandKennel-0
#  * RespondsToCommandKennel-1
#  * RespondsToCommandKennel-2
#  * RespondsToCommandKennel-3
#  * RespondsToCommandKennel-4
#  * RespondsToCommandKennel-5
# New columns added:
#  * Health-0
#  * Health-1
#  * Health-2
#  * Health-3
#  * Health-4
#  * Health-5
# New columns added:
#  * TrafficFear-0
#  * TrafficFear-1
#  * TrafficFear-2
#  * TrafficFear-3
#  * TrafficFear-4
#  * TrafficFear-5
# New columns added:
#  * SitsOnCommand-0
#  * SitsOnCommand-1
#  * SitsOnCommand-2
#  * SitsOnCommand-3
#  * SitsOnCommand-4
#  * SitsOnCommand-5
# New columns added:
#  * GoodWKids-0
#  * GoodWKids-1
#  * GoodWKids-2
#  * GoodWKids-3
#  * GoodWKids-4
#  * GoodWKids-5
# New columns added:
#  * StoolFirm-0
#  * StoolFirm-1
#  * StoolFirm-2
#  * StoolFirm-3
#  * StoolFirm-4
#  * StoolFirm-5
# New columns added:
#  * DownOnCommand-0
#  * DownOnCommand-1
#  * DownOnCommand-2
#  * DownOnCommand-3
#  * DownOnCommand-4
#  * DownOnCommand-5
# New columns added:
#  * EliminationInHouse-0
#  * EliminationInHouse-1
#  * EliminationInHouse-2
#  * EliminationInHouse-3
#  * EliminationInHouse-4
#  * EliminationInHouse-5
# New columns added:
#  * GoodWStrangers-0
#  * GoodWStrangers-1
#  * GoodWStrangers-2
#  * GoodWStrangers-3
#  * GoodWStrangers-4
#  * GoodWStrangers-5
# New columns added:
#  * EliminationInCrate-0
#  * EliminationInCrate-1
#  * EliminationInCrate-2
#  * EliminationInCrate-3
#  * EliminationInCrate-4
#  * EliminationInCrate-5
# New columns added:
#  * Breed-1
#  * Breed-2
#  * Breed-3
#  * Breed-4
#  * Breed-5

# %%
desired_columns = [
    "dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear", "FriendlyWAnimals", "RespondsToCommandKennel", "Health", "TrafficFear", "SitsOnCommand", "GoodWKids", "StoolFirm", "DownOnCommand", "Sex", "EliminationInHouse", "GoodWStrangers", "EliminationInCrate", "Breed"
]

desired_columns_processed = []

# Only keep OHE columns, not the original columns
for col in desired_columns:
    if col in OHE_columns:
        for OHE_col in OHE_columns[col]:
            desired_columns_processed.append(OHE_col)
    else:
        desired_columns_processed.append(col)
        
# Write all columns to 

processed_data = processed_data[desired_columns_processed]

# %%
# Column Mappings for Feature Selections
feature_set_columns = [
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear", "FriendlyWAnimals", "RespondsToCommandKennel", "Health", "TrafficFear", "SitsOnCommand", "GoodWKids", "StoolFirm", "DownOnCommand", "Sex", "EliminationInHouse", "GoodWStrangers", "EliminationInCrate", "Breed"],
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear", "FriendlyWAnimals", "RespondsToCommandKennel", "Health", "TrafficFear", "SitsOnCommand", "GoodWKids", "StoolFirm", "DownOnCommand", "Sex", "EliminationInHouse"],
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear", "FriendlyWAnimals", "RespondsToCommandKennel", "Health", "TrafficFear", "SitsOnCommand"],
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy", "QuietInCrate", "Housemanners", "ComeOnLeash", "EnergyLevel", "NoiseFear"],
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash", "NoInappropriateChewing", "AttendsClasses", "Stairs", "StealsFood", "KnowCommandGetBusy"],
    ["dog_SubStatusCode","ExceriseAmount", "NailCutting", "StaysOnCommand","AttendsHomeSwitches","BehavesWellClass","ChasingAnimals", "JumpOnPeople", "LeftUnattended", "BarksExcessively", "PlaybitePeople", "EliminatesOnRoute", "RaidsGarbage", "CanGivePills", "Color", "OnFurniture","EarCleaning", "CounterSurfingJumpOnDoors", "WalksWellOnLeash", "ComeOffLeash"]
]

mapped_feature_set_columns = []

for some_set in feature_set_columns:
    new_set = []
    for col in some_set:
        if col in OHE_columns:
            for OHE_col in OHE_columns[col]:
                new_set.append(OHE_col)
        else:
            new_set.append(col)
    mapped_feature_set_columns.append(new_set)
    
for some_set in mapped_feature_set_columns:
    set_str = ""
    for col in some_set:
        set_str += "\"" + col + "\", "
    
    print(set_str)
    print()
# Out:
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...
#
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...
#
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...
#
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...
#
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...
#
# "dog_SubStatusCode", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "ExceriseAmount-0", "ExceriseAmount-1", "ExceriseAmount-2", "ExceriseAmount-3", "ExceriseAmount-4", "ExceriseAmount-5", "ExceriseAmount-6", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "NailCutting-0", "NailCutting-1", "NailCutting-2", "NailCutting-3", "NailCutting-4", "NailCutting-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "StaysOnCommand-0", "StaysOnCommand-1", "StaysOnCommand-2", "StaysOnCommand-3", "StaysOnCommand-4", "StaysOnCommand-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "AttendsHomeSwitches-0", "AttendsHomeSwitches-1", "AttendsHomeSwitches-2", "AttendsHomeSwitches-3", "AttendsHomeSwitches-4", "AttendsHomeSwitches-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "BehavesWellClass-0", "BehavesWellClass-1", "BehavesWellClass-2", "BehavesWellClass-3", "BehavesWellClass-4", "BehavesWellClass-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "ChasingAnimals-0", "ChasingAnimals-1", "ChasingAnimals-2", "ChasingAnimals-3", "ChasingAnimals-4", "ChasingAnimals-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "JumpOnPeople-0", "JumpOnPeople-1", "JumpOnPeople-2", "JumpOnPeople-3", "JumpOnPeople-4", "JumpOnPeople-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "LeftUnattended-0", "LeftUnattended-1", "LeftUnattended-2", "LeftUnattended-3", "LeftUnattended-4", "LeftUnattended-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "BarksExcessively-0", "BarksExcessively-1", "BarksExcessively-2", "BarksExcessively-3", "BarksExcessively-4", "BarksExcessively-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "PlaybitePeople-0", "PlaybitePeople-1", "PlaybitePeople-2", "PlaybitePeople-3", "PlaybitePeople-4", "PlaybitePeople-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "EliminatesOnRoute-0", "EliminatesOnRoute-1", "EliminatesOnRoute-2", "EliminatesOnRoute-3", "EliminatesOnRoute-4", "EliminatesOnRoute-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "RaidsGarbage-0", "RaidsGarbage-1", "RaidsGarbage-2", "RaidsGarbage-3", "RaidsGarbage-4", "RaidsGarbage-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "CanGivePills-0", "CanGivePills-1", "CanGivePills-2", "CanGivePills-3", "CanGivePills-4", "CanGivePills-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "Color-1", "Color-2", "Color-3", "Color-4", "Color-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "OnFurniture-0", "OnFurniture-1", "OnFurniture-2", "OnFurniture-3", "OnFurniture-4", "OnFurniture-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "EarCleaning-0", "EarCleaning-1", "EarCleaning-2", "EarCleaning-3", "EarCleaning-4", "EarCleaning-5", "CounterSurfingJumpOnDoors-0", "CounterSurfingJumpOnDoors-1", "CounterSurfingJumpOnDoors-2", "CounterSurfingJumpOnDoors-3", "CounterSurfingJumpOnDoors-4", "CounterSurfingJumpOnDoors-5", "WalksWellOnLeash-0", "WalksWellOnLeash-1", "WalksWellOnLeash-2", "WalksWellOnL ...

# %%
# Output CSVs for each Feature Set
set_names = ['42', '39', '34', '29', '24', '19']

for i in range(len(mapped_feature_set_columns)):
    feature_set = processed_data[mapped_feature_set_columns[i]]
    feature_set.to_csv('puppy_info_feature_set_' + set_names[i] + '.csv', index=False)
