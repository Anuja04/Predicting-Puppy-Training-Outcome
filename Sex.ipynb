# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('PuppyInfo.xls')

# %%
df.head()
# Out:
#    SurveyID  ogr_DogID  Raiser_psn_PersonID ogr_DateStart ogr_DateEnd  \
# 0      2822      20446              28298.0    2015-12-14         NaN
# 1      2096      20427               2481.0    2015-12-12         NaN
# 2      2313      20423              28396.0    2015-12-05         NaN
# 3      2172      20421              28143.0    2015-11-21         NaN
# 4      2154      20420              28326.0    2015-11-21         NaN
#
#                    DOB      Dog  Tattoo         Age               Breed  \
# 0  2015-09-20 00:00:00  Lucille  13L315    4 months                 lab
# 1  2015-09-19 00:00:00  Janelle   9J315  3.5 months  Labrador Retriever
# 2  2015-09-19 00:00:00   Junior   5J315       4 mos          yellow lab
# 3  2015-09-19 00:00:00     Jess   3J315    4 months  Labrador Retriever
# 4  2015-09-19 00:00:00    Jenny   2J315    16 weeks            Labrador
#
#                          ...                          EarsComments  \
# 0                        ...                          haven't done
# 1                        ...                                   NaN
# 2                        ...                                   NaN
# 3                        ...                                   NaN
# 4                        ...                                   NaN
#
#   NailCutting                                     NailsComments  \
# 0         3.0                                      haven't done
# 1         5.0                                               NaN
# 2         5.0                                               NaN
# 3         4.0                                               NaN
# 4         1.0  trying hard, she is very uncomfortable with this
#
#   AttendsClasses                     AttendClassesComments  \
# 0            3.0
# 1            5.0                                       NaN
# 2            5.0                                       NaN
# 3            5.0  We have only missed one optional social.
# 4            5.0                                       NaN
#
#                              NumberClasses3Months BehavesWellClass  \
# 0                                  only 2 classes                3
# 1              all GEB and 3 CABTC classes so far                5
# 2  attends weekly - hasn't missed any classes yet                5
# 3                                  7 or 8 I think                3
# 4                                             all                3
#
#   AttendsHomeSwitches                                   NbrOvernights3Mo  \
# 0                   3                                               none
# 1                   5                                                 na
# 2                   5          one week away with a sitter - he was fine
# 3                   5  She had one three night stay with another fami...
# 4                   3                                               none
#
#                                      GeneralComments
# 0           I did my best but some i wasn't sure of.
# 1  Please send me an electronic copy of this eval...
# 2                                                NaN
# 3  Jess is a very adventurous and bold puppy.  Sh...
# 4                 Haven't had any home switches yet.
#
# [5 rows x 99 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4782 entries, 0 to 4781
# Data columns (total 99 columns):
# SurveyID                     4782 non-null int64
# ogr_DogID                    4782 non-null int64
# Raiser_psn_PersonID          4781 non-null float64
# ogr_DateStart                4776 non-null datetime64[ns]
# ogr_DateEnd                  4135 non-null object
# DOB                          4782 non-null object
# Dog                          4782 non-null object
# Tattoo                       4782 non-null object
# Age                          4779 non-null object
# Breed                        4780 non-null object
# Color                        4779 non-null object
# Sex                          4777 non-null object
# VounteerSupervisor           3843 non-null object
# StaffSupervisor              4779 non-null object
# RaiserCity                   4774 non-null object
# RaiserState                  4778 non-null object
# RaiserZip                    4762 non-null object
# GoodAppetite                 4778 non-null object
# FoodAmount                   3103 non-null float64
# FoodType                     4781 non-null object
# Weight                       4774 non-null object
# Health                       4782 non-null int64
# HealthComments               1296 non-null object
# StoolFirm                    4782 non-null int64
# StoolComments                793 non-null object
# EnergyLevel                  4782 non-null int64
# ExerciseType                 4780 non-null object
# ExericeAmount                4780 non-null object
# EliminationInCrate           4782 non-null int64
# EliminationCrateComments     570 non-null object
# QuietInCrate                 4782 non-null int64
# CrateQuietComments           1710 non-null object
# RespondsToCommandKennel      4782 non-null int64
# KennelCommandComments        1110 non-null object
# NoInappropriateChewing       4782 non-null int64
# ChewingComments              2097 non-null object
# Housemanners                 4782 non-null int64
# HousemannersComments         1878 non-null object
# LeftUnattended               4782 non-null int64
# LeftUnattendedComments       2394 non-null object
# EliminationInHouse           4782 non-null int64
# EliminationHouseComments     1071 non-null object
# PlaybitePeople               4782 non-null int64
# PlaybiteComments             2083 non-null object
# StealsFood                   4782 non-null int64
# StealFoodComments            1493 non-null object
# OnFurniture                  4782 non-null int64
# OnFurnitureComments          1761 non-null object
# BarksExcessively             4782 non-null int64
# BarksExcessivelyComments     2393 non-null object
# RaidsGarbage                 4782 non-null int64
# RaidsGarbageComments         1682 non-null object
# CounterSurfingJumpOnDoors    4782 non-null int64
# CountersDoorsComments        1317 non-null object
# JumpOnPeople                 4782 non-null int64
# JumpsComments                2860 non-null object
# FriendlyWAnimals             4782 non-null int64
# FriendlyWAnimalsComments     1441 non-null object
# GoodWKids                    4782 non-null int64
# KidsComments                 1182 non-null object
# GoodWStrangers               4782 non-null int64
# StrangerComments             884 non-null object
# WalksWellOnLeash             4782 non-null int64
# WalkingComments              2343 non-null object
# KnowCommandGetBusy           4782 non-null int64
# GetBusyComments              1095 non-null object
# EliminatesOnRoute            4782 non-null int64
# EliminateRouteComments       1772 non-null object
# ChasingAnimals               4782 non-null int64
# ChaseComment                 2356 non-null object
# TrafficFear                  4782 non-null int64
# TrafficComments              1262 non-null object
# NoiseFear                    4782 non-null int64
# NoiseComments                1301 non-null object
# Stairs                       4782 non-null int64
# StairsComments               953 non-null object
# SitsOnCommand                4782 non-null int64
# SitComments                  658 non-null object
# DownOnCommand                4782 non-null int64
# DownComments                 864 non-null object
# StaysOnCommand               4782 non-null int64
# StayComments                 1743 non-null object
# ComeOnLeash                  4782 non-null int64
# ComeOnLeashComments          669 non-null object
# ComeOffLeash                 4782 non-null int64
# ComeOffLeashComments         1576 non-null object
# CanGivePills                 4782 non-null int64
# PillsComments                1323 non-null object
# EarCleaning                  4782 non-null int64
# EarsComments                 1088 non-null object
# NailCutting                  4781 non-null float64
# NailsComments                2106 non-null object
# AttendsClasses               4780 non-null float64
# AttendClassesComments        115 non-null object
# NumberClasses3Months         4513 non-null object
# BehavesWellClass             4782 non-null int64
# AttendsHomeSwitches          4782 non-null int64
# NbrOvernights3Mo             4365 non-null object
# GeneralComments              2870 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(38), object(56)
# memory usage: 3.6+ MB

# %%
all_ages = data.Age.map(lambda x: str(x).lower()).unique()
all_ages
# Out:
# array(['4 months', '3.5 months', '4 mos', '16 weeks', '14 weeks',
#        '3 months', '4mnths', '15 weeks', '3months', '3 1/2 months',
#        '3 1/2 months old', '20 weeks', '3mo', '5 months', '5months',
#        '5 month', '4 mos.', '3  months', '5mod', '3+ months', '4 month',
#        '16 wks', 'almost 4 months', '15.5 weeks', '15.7 weeks',
#        '5.5 months', '4.5 months', '4 mts', '4 mo', '5 mos', '18 weeks',
#        '5mo/3wks', '4 1/2 months', '13 weeks', '21 weeks', '3+months',
#        '6 months', '3.5 mos', '6 mos', '4 months old', '17 weeks',
#        '8 months', '18weeks', '8 mo.', '4mo', '4 months +10 days',
#        '4 months, 3days', '4 monthss', '7 months', '4 months and 2 weeks',
#        '8 mos', '4.5 mos', '7 1/2 mos', '5 1/2 months', '8 mths',
#        '8.5 months', '15 weeks old', '8 mos.', '4mos', '7 months 30 days',
#        'almost 8 months', '7-1/2 months', '4', '7 month', '19 weeks',
#        '4 months, 1 day', '10 mo.', '9 mos', '20 weeks old', '9 months',
#        '8 1/2 months', '9 1/2 months', '5 months 3 weeks', '10 months',
#        '3mo 1w', '8 mo', 'about 4 months', '11 months', '14 wks',
#        'almost 8 mos', '6monthsc', '8 mth', '8 months old', '12 weeks',
#        '4 months, 2 weeks', 'almost 5 months', '12 months',
#        '3 months, 2 weeks', '4.5 mo', '9 mo.', '1 yr', '3.5mos', '7mos',
#        'aprrox 4 months', '8months', '13 months', '10 weeks', '11mo',
#        '3 1/2 mos.', '8 months 3 weeks', '7.5 mo', '3.5 mo',
#        '3 months, 3 weeks', '3 months - 20 days', "4mo's",
#        '10 months, 3 weeks', '1 year', '7.5 months', '13 mos.',
#        '14 months', '4months', '13 mo', '5 mo', '1 year 1 month',
#        '8+ months', '1', '7.5 mos', '6 1/2 months', '7 months 3 weeks',
#        '5 and i/2 months', '1yr and 1month', '7 mo', '12 mo.',
#        '12.5 months', '8 moa', '12 mos', '~5 months', '6months',
#        '1 yr, 1 mo', '5 mo.', '4.5 monts', '13.5mos', '9  1/2  months',
#        '1 years old', 'approx. 1 year', '3  3/4 months', '13 mounths',
#        'almost 13 months', '13.25 months', '8-1/2 months', '7 mos',
#        '12  1/2 months', '22 weeks', '13 1/2 months', '5 1/2 momths',
#        '1 yr.', '13.5 months', '4 months, 18 days', '7 months 19 days',
#        '7 1/2 months', 'just under 13 weeks', '9 mo', '12weeks',
#        'almost 14 months', '8 month', '9mnths', '1yr 1month',
#        '1 year 2 months', '7 mo.', '4 months 2 weeks', '9mo', '19.5 weeks',
#        '13+ months', '15weeks', '7months', '13 mths', '14.5 months', '1yr',
#        '7m', '4 mo.', ' 4 months', '11+ months', '4 months + 1 week',
#        '8 months, 3 weeks', 'almost 9 months', '3 months 1 week',
#        '17 wks on wt date', '2 months, 3 weeks', '1 year 3 weeks',
#        '18 wks', '4 months 14 days', '11 monthes', '13 month',
#        '4 and a half months', '8m', '4 months ( in 4 days)',
#        '4 months and 1 day', '4.75 months', '21 weeks old', '15 1/2 weeks',
#        '12.5', '15 months', '13 mos', '5-1/2 months', '9 months 6 days',
#        '13 months 6 days', '4.5', '4.5months', '21 weeks, 2 days',
#        '6 mts.', '10 mts.', '5 months old', '6.5 months', '8.75 months',
#        '12 + months', '13', '6mths', '11 1/2 months', '13mo', '7 1/2 mo',
#        '9.5 months', '7.5 m', '8mos', '7months, 3weeks',
#        '7 months/almost 8 months', '10 1/2 months', '10mo', '17mo',
#        '11months', '1 year and 1 month', '14 mos', '10 mos',
#        '1 yr 2 months', '12.5 mo', 'one year', '17 mo.', '13 mo.',
#        '9months', '9mos', '8mo', '8 mths.', '15 mos.', '15 months (1yr3m)',
#        '12 1/2 months', '11mos', '10 mts', '3 months old', '10.5 months',
#        '14+ months', '1.1', '11', '3 1/2 mos', '1 yr. 1 month', '15wks',
#        '1yr and 3wks', '10 mons.', '3 mo.3wks', '11 mos.', '20 wks',
#        '1 yr 2 wks', '12months', '12 months.', 'nan', ' 14 months',
#        'approx 20 weeks', '14', '4 1/2 mo', '12 mos.', '15mths',
#        '16 months', '7mo.', '4 mths', '4 months, 1 week',
#        '4 months, 12 days', '7-8 months', '12months & 2 weeks',
#        'four months', '7 mths', '4 months 3 weeks', '9 weeks', '10wks',
#        '4 mo+', '?', '~12 weeks', '5mos',
#        '1 year, 1 month and 21 days or or 13 months 21 days...',
#        'almost 6 months', '25 weeks', '8-9 months', '8 mo. on 3/21/14',
#        '4 mo. 9 days', '14 weeks+', '9 months 9 days', '16wks', '4mo.',
#        '8 1/2 mo.', '3/1/2 months', '17 wks', '17.5', '4.5mo', '18 months',
#        '4 months + 26 days', '7 1/2 month', '14 1/2 weeks', '4.75 mo',
#        '10 months old', '8 1/2 mos.', '4 mnths', '7months  almost 8mnths',
#        'seven months', '3 mo', '7.5 months old', '4 months 21 days',
#        '5 months (approx)', '7.5 mos.', '8 months 8 days',
#        '18 weeks and 2 days', '14 mo', '14months', '6mo', '6 mo',
#        '11.5 weeks', '11 months +', '15wks 2days', '13mo3wks4days',
#        '14month', '8 3/4  months', '13 wks', '14 mths', '24  1/2 weeks',
#        '4 mt  3 wks', '4 mths.', '5 weeks', '41/2 months',
#        '41 weeks, approx 9.5 months', '1year', 'eight months',
#        '12 months / 15 days', '4 mo 3 wks', '1yr,3wks', '13-1/2 months',
#        '18 1/2 weeks', '14 weeks on 21 march, 16 wks on apr4',
#        '8 + months', '16 mo', '4 mon.', '14 1/2 months', '17 months',
#        '17.5  weeks', '3 3/4 months', '7.25 months', 'about 8 months',
#        '16', '1 year 3 months', '1 y 2 mo', '1 year 5 months', '1 yrs old',
#        '11weeks', '1 year one month', '6 months 10 days', '1 yr 1 mth',
#        '33 weeks', 'almost 10 months', '7 mos.', '13 mos (in 2 days)',
#        '10 mos.', '5 mos.', '17 weeks 1 day-approximately 4 months',
#        '8 months on 05/12/13', '16.5 months', ' 12 months', '14.5',
#        '10 mo', '16weeks', '12m', '13months', '14 mos.', '9 mos.',
#        'almost 8 months (on march 26)', '13 3/4 months', '3 mos',
#        '1 yr, 2 mos', 'almost 5months', '8 3/4 months',
#        'almost four months', '3 months 7 days',
#        '10 months (11 months on june 2nd)', '1yr. 1mo.', '2', '10months',
#        '5+ months', '7 months 10 days', '10 month', '3 months, 15 days',
#        '9.5 mos.', '7 mo 2 wks', '1yr. & 2 mths', '10mths', '5 3/4 months',
#        '15 mos', '3 mos 2 wk', '15 1/2 mos.', '5mo', '7 1/2months',
#        '14mos', '6 1/2 mo', '4 months, 20 days',
#        '1 year and almost 1 month', '15.5 months', '4 monthd',
#        '8 months, 2 weeks', '11 months+', '14 month', '2 months', '6mos.',
#        '13mos', '11.5 months', '13 months old', '4 months 3 days',
#        '1year and 3months', '10', '13mo.', '5 mths.', '7 1/2 mths',
#        '16 mo.', '4 3/4 months', '3 mths', '18.5 weeks', '5.5',
#        '14.5 weeks', '81/2 months', '5 moths', '13 months (almost)',
#        '11months 2weeks', '5 1/2 months old', '17 weeks 2 days',
#        'one year one month', '4 monthw', '22 weeks (5 months)',
#        '8 months (37 weeks)', '7 momths', '4 1/2 mos', '1.5 years',
#        '1 year and 2 months', '12+ months', '4.5 m', '10+ months',
#        '24weeks', '4.75', '71/2 months', '1 year 12 days', '5.5 mo',
#        '7 3/4 months', '16months', '1yr  2mts. this week', '8 mts',
#        '10 months 3 weeks', '1 year 1 1/2 month', '11 months old',
#        '4+ months', 'approx 9 months', '14 months old', '6 mons.',
#        '11 mons', '13  months', '7 mts', '5.5 mos', '11.5 mo',
#        '5 months as of jan. 14', '8-1/2 mo.', '5mos.', '6.5', '12mos',
#        '5 and 1/2 months', '7', '3.5months', '4 months 1 week', '23 weeks',
#        '9 months old', '3-1/2 months', '6 months (almost)',
#        'almost 15 months', '12 mo', '12 month', '5+', '9mos.', ' 6 mos',
#        '15 wks', ' 13 mos', '9', '10mos.', '5 months 2 weeks', '11 m',
#        '26 weeks', '6-1/2 moths old', '6.5 mos', 'almost 1 year old',
#        '6 mo.', '5mos 26 days', 'six months', '11 mos',
#        '1 year three months', '6 mos.', '11.11 months', '8 3/4 mo.',
#        '8 months soon', '14mo', '1 year, 2 month', '12.1', ' 5 months',
#        'five months', '~9 months.', '13 and a half months', '8 months+',
#        '6.5 mos.', '8 1/2 mos', '19 weeks (~4.5 months)', '15',
#        '5-6 months', '1 year and 3 weeks', '4 months 5 days', '8 monthsq',
#        '10.5 mths', '4 months, 3 days', '8 months/6 days', '8mo.',
#        '3.5 mo.', '8  months', '9.9 months', '23 weeks (4 months 3 weeks)',
#        '8.5', '1 yr 4 month', '5 and a half months', '7  mo. 2 weeks',
#        '19 wks', '11 weeks', 'six months at eval', '12.5 weeks',
#        '10.5 wks', 'almost 6 mo', '5 1/2mt', '12 months & 1 week',
#        '10 mths', 'around 9 months', '1 year, 1 day', '4 mos + 3 wks',
#        '4 1/2 mos.', '11 mo.', '14 mo.', 'almost one year',
#        '1 year 1.5 months', 'almost one year!', '4 months (almost!)',
#        '7 mth', '4 months and 17 days', '1.3', '14mo.', '17 weeks old',
#        '3 1/2 mo.', 'almost 12 months', '4 1/2  mos', '8 3/4 mo',
#        '12 mons', '24 weeks', '6.75 months', '8 months (almost 9 months)',
#        '8 months and 3 weeks', 'close to 10 months', '8.5 mo', '12 1/2 mo',
#        '4 1/2  mths.', 'almost 11 months', '3 months and 3 weeks old',
#        '6 mon', '1 1/2 years', 'almost 18 months', '6mos', '15mos',
#        '13 months at time of w&t', '~9 months', '6 month', '13.5 weeks',
#        '4 months and one week', '5 1/2 mos', 'almost 1 yr old', '28 weeks',
#        'almost a year', '10 1/2 mos.', '14  months', '11.9months',
#        '9.75 months', '7 mon', 'almost 5 months.',
#        '23 weeks (5 1/2 months)', '9.5m',
#        '3 months and 16 days if my math serves me', '7 months 1 day',
#        'one year and one day', '3 months,7 days', '14 m', '13.75  weeks',
#        '7 months, 3 weeks', '2.5 months', '14.75 months', 'jan. 30, 2010',
#        ' 8 1/2 months', '15 month', '3 months 2 days', '1year, 1month',
#        '1 year 4 months', '5 months, and one week', '12 weeks 2 days',
#        '6.5months', '16 mos', '9 monghs', '1 year, 2 months',
#        '3 months and 3 weeks', '10 months 2 weeks as of 10-13-2010',
#        '12 1/2 weeks', '6 months and 1 week', '11 mos 3 weeks',
#        '12.5 months old', '15 1/2 months', '8 months and 17 days',
#        '6 months and 7 days', '3 months, 10 days', '17 1/2 months',
#        '16 1/2 months', '43/4 months', '11 weeks old', '8  1/2 months',
#        '11 mo', 'almost 7 mts', '11 mts', '15 mts', 'almost 1yrs old',
#        '15months', '13 months 2 weeks', '6 months 3 weeks', '6 mths.',
#        '16-1/2 months', '6', 'almost 10 mos.', '5 1/2 mos.', '9-1/2 mos',
#        '8mths', '8.5 mos', '13 m', '1 year old', '1 year and 3 months',
#        '1 year and half a month', '48', '39 weeks', '1yr 3 weeks',
#        '11 months 17 days', '11 3/4 months', '9 months 22 days',
#        '1 year, 2 months, 28 days', '13 months 22 days', '10m',
#        '11.9 months', '1year, 5 weeks', '12', '15mo.', '15 mo', '17months'], dtype=object)

# %%
target_for_values = {
'F': ['bitch','remale','f','Female','fem','fema;e','F','    F','Femae','Femail','Femaile','Femal','Femal3','Female','Femalw','femle','FEMALE','female','Girl','ID#2099','girl','n/a','None','own','Unknown','1364 & 655','1112/1329','065 102 601','2052','2235','11796','1972','1677','1649','1590','1395','1070','219','0','696','1018','ID# 2099','femal','femalw','Famale','femaile','femail']}

# %%
for k, v in target_for_values.items():
    df.loc[df.Sex.isin(v), 'Sex'] = k

# %%
target_for_values = {
'M': ['Male','1110','1231','1627','1644','1766','1870','2019','??','1JJ11','boy','Crate from Val and Jim Hazlin','don\'t have one.','M - neutered','maie','Mail','Maile','Make','make','Male - neutered','male (neutered)','"Male, neutered"','Male1832','mine doesn\'t have a number?','N/A','NA','Neutered Male','new crate','none','own crate','Weren\'t given a crate','m','male','MALE','Male', 'Male','neutered mail','mail','Male, neutered',' Neutered Male']}

# %%
for k, v in target_for_values.items():
    df.loc[df.Sex.isin(v), 'Sex'] = k

# %%
df['Sex'].value_counts()
# Out:
# M    2400
# F    2382
# Name: Sex, dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Sex'].fillna('M', inplace = True)

# %%
df['Sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Sex']=df['Sex'].map({'F':0, 'M':1}).astype(int)

# %%
df.to_excel('PuppyInfoS.xls',index=False)

# %%
select = ['ogr_DogID', 'Raiser_psn_PersonID', 'Age', 'Breed', 'Color', 'Sex', 'Health', 'EnergyLevel', 'RespondsToCommandKennel', 
          'Housemanners', 'LeftUnattended', 'StealsFood', 'FriendlyWAnimals', 'SitsOnCommand', 
          'DownOnCommand', 'StaysOnCommand', 'AttendsClasses', 'AttendsHomeSwitches', 'BehavesWellClass', 
          'ExerciseType', 'ExericeAmount', 'JumpOnPeople', 'WalksWellOnLeash'
          ]

# %%
data = df[select]

# %%
correlation = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation, vmax=1, square=True,annot=True,cmap='viridis')

plt.title('Correlation between different fearures')
